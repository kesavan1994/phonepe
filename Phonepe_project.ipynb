# %%
# !git clone https://github.com/PhonePe/pulse.git
# Out:
# Cloning into 'pulse'...
# Updating files:  46% (2063/4443)
# Updating files:  47% (2089/4443)
# Updating files:  48% (2133/4443)
# Updating files:  49% (2178/4443)
# Updating files:  50% (2222/4443)
# Updating files:  51% (2266/4443)
# Updating files:  52% (2311/4443)
# Updating files:  53% (2355/4443)
# Updating files:  54% (2400/4443)
# Updating files:  55% (2444/4443)
# Updating files:  56% (2489/4443)
# Updating files:  57% (2533/4443)
# Updating files:  58% (2577/4443)
# Updating files:  59% (2622/4443)
# Updating files:  60% (2666/4443)
# Updating files:  61% (2711/4443)
# Updating files:  62% (2755/4443)
# Updating files:  63% (2800/4443)
# Updating files:  64% (2844/4443)
# Updating files:  65% (2888/4443)
# Updating files:  66% (2933/4443)
# Updating files:  67% (2977/4443)
# Updating files:  68% (3022/4443)
# Updating files:  69% (3066/4443)
# Updating files:  70% (3111/4443)
# Updating files:  71% (3155/4443)
# Updating files:  72% (3199/4443)
# ...

# %%
# Create Data frame for Aggregated\ Transation

import os
import json
import pandas as pd

path="C:\\Users\\91909\\firstprogram\\Phonepe\\pulse\\data\\aggregated\\transaction\\country\\india\\state\\"


agg_tran_st=os.listdir(path)
agg_tran_st

ats={'State':[], 'Year':[],'Quater':[],'Transacion_type':[], 'Transacion_count':[], 'Transacion_amount':[]}
for i in agg_tran_st:
  tr_st=path+i+'/'
  agg_year=os.listdir(tr_st)
  for j in agg_year:
    tr_yr=tr_st+j+'/'
    agg_yr_list=os.listdir(tr_yr)
    for k in agg_yr_list:
      tr_j=tr_yr+k
      data=open(tr_j,'r')
      d=json.load(data)
      for z in d['data']['transactionData']:
        Name=z['name']
        Count=z['paymentInstruments'][0]['count']
        Amount=z['paymentInstruments'][0]['amount']
        ats['State'].append(i)
        ats['Year'].append(j)
        ats['Quater'].append(int(k.strip('.json')))
        ats['Transacion_amount'].append(Amount)
        ats['Transacion_count'].append(Count)
        ats['Transacion_type'].append(Name)

ats=pd.DataFrame(ats)      
ats['State']=ats['State'].str.replace('-',' ')
ats['Transacion_type']=ats['Transacion_type'].str.replace('-',' ')

ats
# Out:
#                           State  Year  Quater           Transacion_type  \
# 0     andaman & nicobar islands  2018       1  Recharge & bill payments
# 1     andaman & nicobar islands  2018       1     Peer to peer payments
# 2     andaman & nicobar islands  2018       1         Merchant payments
# 3     andaman & nicobar islands  2018       1        Financial Services
# 4     andaman & nicobar islands  2018       1                    Others
# ...                         ...   ...     ...                       ...
# 3589                west bengal  2022       4     Peer to peer payments
# 3590                west bengal  2022       4         Merchant payments
# 3591                west bengal  2022       4  Recharge & bill payments
# 3592                west bengal  2022       4        Financial Services
# 3593                west bengal  2022       4                    Others
#
#       Transacion_count  Transacion_amount
# 0                 4200       1.845307e+06
# ...

# %%
ats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3594 entries, 0 to 3593
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   State              3594 non-null   object
#  1   Year               3594 non-null   object
#  2   Quater             3594 non-null   int64
#  3   Transacion_type    3594 non-null   object
#  4   Transacion_count   3594 non-null   int64
#  5   Transacion_amount  3594 non-null   float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 168.6+ KB

# %%
# !pip install numerize
# Out:
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from numerize import numerize
print()
print(numerize.numerize(100000))
print(numerize.numerize(1234567))
print(numerize.numerize(3533987.2301130000))
# Out:
# 100K
# 1.23M
# 3.53M

# %%
ats['Transacion_type'].unique()
# Out:
# array(['Recharge & bill payments', 'Peer to peer payments',
#        'Merchant payments', 'Financial Services', 'Others'], dtype=object)

# %%
# !pip install Babel
# Out:
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#      ---------------------------------------- 9.5/9.5 MB 9.1 MB/s eta 0:00:00
# ...

# %%
os.getcwd()
# Out:
# 'C:\\Users\\91909\\firstprogram\\Phonepe'

# %%
# !pip install mysql-connector-python
# Out:
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install pymysql
# Out:
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import mysql.connector
mydb=mysql.connector.connect(
    host='localhost',
    user='root',
    password='',
)

# %%
print(mydb)

# %%
mycursor=mydb.cursor(buffered=True)

# %%
mycursor.execute("show databases")

# %%
for i in mycursor:
    print(i)
# Out:
# ('apple',)
# ('cencuse',)
# ('constraints',)
# ('diabetes',)
# ('hospital',)
# ('img',)
# ('information_schema',)
# ('mysql',)
# ('mytable',)
# ('performance_schema',)
# ('phonepe',)
# ('phpmyadmin',)
# ('test',)

# %%
mycursor.execute("CREATE DATABASE Phonepe")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     607                 query = query.encode("utf-8")
# --> 608             self._cmysql.query(
#     609                 query,
#
# MySQLInterfaceError: Can't create database 'phonepe'; database exists
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16488\4079753335.py in <cell line: 1>()
# ----> 1 mycursor.execute("CREATE DATABASE Phonepe")
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     328
#     329         try:
# ...

# %%
mycursor.execute("USE Phonepe")

# %%
mycursor.execute("""CREATE TABLE IF NOT EXISTS agg_trans(
                        State TEXT,Year TEXT,Quater TEXT,Transacion_type TEXT,Transacion_count TEXT,Transacion_amount TEXT)"""
                )

# %%
insert=ats.values.tolist()

# %%
query='INSERT INTO agg_trans VALUES(%s,%s,%s,%s,%s,%s)'
mycursor.executemany(query,insert)

# %%
d=mycursor.execute("""SELECT * FROM agg_trans WHERE State= 'tamil nadu' AND Year='2018' AND Quater='1' AND 
                   Transacion_type='Merchant payments' AND Transacion_amount>0""" )
d=mycursor.fetchall()
for i in d:
    print(i)
# Out:
# ('tamil nadu', '2018', '3', 'Merchant payments', '1290978', '733189649.5729834')

# %%
#Create Data frame for Aggregated\user

import os
import json
import pandas as pd

path="C:\\Users\\91909\\firstprogram\\Phonepe\\pulse\\data\\aggregated\\user\\country\\india\\state\\"


agg_user_st=os.listdir(path)
agg_user_st

aus={'State':[], 'Year':[],'Quater':[],'Mobile_brand':[], 'Mobile_count':[], 'Mobile_percentage':[]}
for i in agg_user_st:
  tr_st=path+i+'/'
  agg_year=os.listdir(tr_st)
  for j in agg_year:
    tr_yr=tr_st+j+'/'
    agg_yr_list=os.listdir(tr_yr)
    for k in agg_yr_list:
      tr_j=tr_yr+k
      data=open(tr_j,'r')
      d=json.load(data)
      if d['data']["usersByDevice"] == None :
            continue
      else:      
          for z in d['data']["usersByDevice"]:
#              print(z['brand'],i,j,int(k.strip('.json')))
             Brand=z['brand']
             Count=z['count']
             Percent=z['percentage']
             aus['State'].append(i.replace('-',' '))
             aus['Year'].append(j)
             aus['Quater'].append(int(k.strip('.json')))
             aus['Mobile_percentage'].append(Percent)
             aus['Mobile_count'].append(Count)
             aus['Mobile_brand'].append(Brand)

aus=pd.DataFrame(aus)   
# aus['State']=ats['State'].str.replace('-',' ')

aus
# Out:
#                           State  Year  Quater Mobile_brand  Mobile_count  \
# 0     andaman & nicobar islands  2018       1       Xiaomi          1665
# 1     andaman & nicobar islands  2018       1      Samsung          1445
# 2     andaman & nicobar islands  2018       1         Vivo           982
# 3     andaman & nicobar islands  2018       1         Oppo           501
# 4     andaman & nicobar islands  2018       1      OnePlus           332
# ...                         ...   ...     ...          ...           ...
# 6727                west bengal  2022       1       Lenovo        330017
# 6728                west bengal  2022       1      Infinix        284678
# 6729                west bengal  2022       1         Asus        280347
# 6730                west bengal  2022       1        Apple        277752
# 6731                west bengal  2022       1       Others       2196334
#
#       Mobile_percentage
# 0              0.247033
# 1              0.214392
# ...

# %%
x=mycursor.execute("SELECT * FROM agg_trans")
x=mycursor.fetchall()
for row in x:
    print(row)
# Out:
# ('andaman & nicobar islands', 2018, 1, 'Recharge & bill payments', 4200, '1845307.4673655091')
# ('andaman & nicobar islands', 2018, 1, 'Peer to peer payments', 1871, '12138655.299749982')
# ('andaman & nicobar islands', 2018, 1, 'Merchant payments', 298, '452507.168646613')
# ('andaman & nicobar islands', 2018, 1, 'Financial Services', 33, '10601.419933464953')
# ('andaman & nicobar islands', 2018, 1, 'Others', 256, '184689.8662902223')
# ('andaman & nicobar islands', 2018, 2, 'Recharge & bill payments', 6735, '2320944.731074479')
# ('andaman & nicobar islands', 2018, 2, 'Peer to peer payments', 3575, '24511925.231047668')
# ('andaman & nicobar islands', 2018, 2, 'Merchant payments', 603, '1024491.0133579008')
# ('andaman & nicobar islands', 2018, 2, 'Financial Services', 59, '121336.0270987509')
# ('andaman & nicobar islands', 2018, 2, 'Others', 368, '359838.50537474576')
# ('andaman & nicobar islands', 2018, 3, 'Recharge & bill payments', 8636, '4343504.868377829')
# ...

# %%
aus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6732 entries, 0 to 6731
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   State              6732 non-null   object
#  1   Year               6732 non-null   object
#  2   Quater             6732 non-null   int64
#  3   Mobile_brand       6732 non-null   object
#  4   Mobile_count       6732 non-null   int64
#  5   Mobile_percentage  6732 non-null   float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 315.7+ KB

# %%
mycursor.execute("""CREATE TABLE IF NOT EXISTS agg_user(
                        State TEXT,Year TEXT,Quater TEXT,Mobile_brand TEXT,Mobile_count TEXT,Mobile_percentage TEXT)"""
                )

# %%
query="""INSERT INTO agg_user VALUES(%s,%s,%s,%s,%s,%s)"""
data=aus.values.tolist()
mycursor.executemany(query,data)

# %%
c=mycursor.execute("""SELECT * FROM agg_user""")
c=mycursor.fetchall()
for row in c:
    print(row)
# Out:
# ('andaman & nicobar islands', '2018', '1', 'Xiaomi', '1665', '0.2470326409495549')
# ('andaman & nicobar islands', '2018', '1', 'Samsung', '1445', '0.21439169139465875')
# ('andaman & nicobar islands', '2018', '1', 'Vivo', '982', '0.1456973293768546')
# ('andaman & nicobar islands', '2018', '1', 'Oppo', '501', '0.07433234421364986')
# ('andaman & nicobar islands', '2018', '1', 'OnePlus', '332', '0.04925816023738872')
# ('andaman & nicobar islands', '2018', '1', 'Realme', '316', '0.04688427299703264')
# ('andaman & nicobar islands', '2018', '1', 'Apple', '229', '0.03397626112759644')
# ('andaman & nicobar islands', '2018', '1', 'Motorola', '226', '0.03353115727002967')
# ('andaman & nicobar islands', '2018', '1', 'Lenovo', '202', '0.02997032640949555')
# ('andaman & nicobar islands', '2018', '1', 'Huawei', '158', '0.02344213649851632')
# ('andaman & nicobar islands', '2018', '1', 'Others', '684', '0.10148367952522255')
# ...

# %%
mycursor.execute("""SELECT * FROM agg_user WHERE State='west bengal',Year='2021' """)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     564                 query = query.encode("utf-8")
# --> 565             self._cmysql.query(
#     566                 query,
#
# MySQLInterfaceError: You have an error in your SQL syntax; check the manual that corresponds to your MariaDB server version for the right syntax to use near 'Year='2021'' at line 1
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2392\3345198724.py in <cell line: 1>()
# ----> 1 mycursor.execute("""SELECT * FROM agg_user WHERE State='west bengal',Year='2021' """)
#
# ...

# %%
# Create Data frame for Map\transaction

import os
import json
import pandas as pd

path="C:\\Users\\91909\\firstprogram\\Phonepe\\pulse\\data\\map\\transaction\\hover\\country\\india\\state\\"


map_trans_st=os.listdir(path)
map_trans_st

mts={'State':[], 'Year':[],'Quater':[],'District':[], 'District_count':[], 'District_amount':[]}
for i in map_trans_st:
  tr_st=path+i+'/'
  agg_year=os.listdir(tr_st)
  for j in agg_year:
    tr_yr=tr_st+j+'/'
    agg_yr_list=os.listdir(tr_yr)
    for k in agg_yr_list:
      tr_j=tr_yr+k
      data=open(tr_j,'r')
      d=json.load(data)
      if d['data']["hoverDataList"] == None :
            continue
      else:      
          for z in d['data']["hoverDataList"]:
#              print(z['brand'],i,j,int(k.strip('.json')))
             Name=z['name']
             Count=z['metric'][0]['count']
             Amount=z['metric'][0]['amount']
             mts['State'].append(i.replace('-',' '))
             mts['Year'].append(j)
             mts['Quater'].append(int(k.strip('.json')))
             mts['District_amount'].append(Amount)
             mts['District_count'].append(Count)
             mts['District'].append(Name.replace('district',''))

mts=pd.DataFrame(mts)       
mts
# Out:
#                            State  Year  Quater                   District  \
# 0      andaman & nicobar islands  2018       1  north and middle andaman
# 1      andaman & nicobar islands  2018       1             south andaman
# 2      andaman & nicobar islands  2018       1                  nicobars
# 3      andaman & nicobar islands  2018       2  north and middle andaman
# 4      andaman & nicobar islands  2018       2             south andaman
# ...                          ...   ...     ...                        ...
# 14631                west bengal  2022       4                     nadia
# 14632                west bengal  2022       4                   birbhum
# 14633                west bengal  2022       4           purba medinipur
# 14634                west bengal  2022       4                    maldah
# 14635                west bengal  2022       4                 darjiling
#
#        District_count  District_amount
# 0                 442     9.316631e+05
# ...

# %%
mycursor.execute("""CREATE TABLE IF NOT EXISTS map_trans(
                        State TEXT,Year TEXT,Quater TEXT,District TEXT,District_count TEXT,District_amount TEXT)"""
                )

# %%
query="""INSERT INTO map_trans VALUES(%s,%s,%s,%s,%s,%s)"""
data=mts.values.tolist()
mycursor.executemany(query,data)

# %%
c=mycursor.execute("SELECT * FROM map_trans ")
c=mycursor.fetchall()
for i in c:
    print(i)
# Out:
# ('andaman & nicobar islands', '2018', '1', 'north and middle andaman ', '442', '931663.0770939873')
# ('andaman & nicobar islands', '2018', '1', 'south andaman ', '5688', '12560249.34366581')
# ('andaman & nicobar islands', '2018', '1', 'nicobars ', '528', '1139848.801225994')
# ('andaman & nicobar islands', '2018', '2', 'north and middle andaman ', '825', '1317863.0834906558')
# ('andaman & nicobar islands', '2018', '2', 'south andaman ', '9395', '23948235.51634325')
# ('andaman & nicobar islands', '2018', '2', 'nicobars ', '1120', '3072436.9081196385')
# ('andaman & nicobar islands', '2018', '3', 'north and middle andaman ', '1283', '4901529.518499676')
# ('andaman & nicobar islands', '2018', '3', 'south andaman ', '13511', '44268112.46425246')
# ('andaman & nicobar islands', '2018', '3', 'nicobars ', '1471', '6387829.151558982')
# ('andaman & nicobar islands', '2018', '4', 'north and middle andaman ', '2137', '7955635.917688001')
# ...

# %%
# Create Data frame for Map\Users

import os
import json
import pandas as pd

path="C:\\Users\\91909\\firstprogram\\Phonepe\\pulse\\data\\map\\user\\hover\\country\\india\\state\\"


map_user_st=os.listdir(path)
map_user_st

mus={'State':[],'Year':[],'Quater':[],'District':[], 'registeredUsers':[], 'appOpens':[]}
for i in map_user_st:
  tr_st=path+i+'/'
  agg_year=os.listdir(tr_st)
  for j in agg_year:
    tr_yr=tr_st+j+'/'
    agg_yr_list=os.listdir(tr_yr)
    for k in agg_yr_list:
      tr_j=tr_yr+k
      data=open(tr_j,'r')
      d=json.load(data) 
     
      for z in d['data']['hoverData'].keys():
                
                 mus['District'].append(z.replace('district',''))

      for l in d['data']['hoverData'].values():
             r=l
             for key,val in r.items():
                 if key =='registeredUsers' :
                     mus['registeredUsers'].append(val)
    
             for key,val in r.items():
                 if key =='appOpens' :
                     mus['appOpens'].append(val)     

     
             mus['State'].append(i.replace('-',' '))
           
             mus['Year'].append(j)
             mus['Quater'].append(int(k.strip('.json')))
mus= pd.DataFrame(mus)
mus
# Out:
#                            State  Year  Quater                   District  \
# 0      andaman & nicobar islands  2018       1  north and middle andaman
# 1      andaman & nicobar islands  2018       1             south andaman
# 2      andaman & nicobar islands  2018       1                  nicobars
# 3      andaman & nicobar islands  2018       2  north and middle andaman
# 4      andaman & nicobar islands  2018       2             south andaman
# ...                          ...   ...     ...                        ...
# 14635                west bengal  2022       4                     nadia
# 14636                west bengal  2022       4                   birbhum
# 14637                west bengal  2022       4           purba medinipur
# 14638                west bengal  2022       4                    maldah
# 14639                west bengal  2022       4                 darjiling
#
#        registeredUsers  appOpens
# 0                  632         0
# ...

# %%
mycursor.execute("""CREATE TABLE IF NOT EXISTS map_user(
                        State TEXT,Year TEXT,Quater TEXT,District TEXT,registeredUsers TEXT,appOpens TEXT)"""
                )

# %%
query="""INSERT INTO map_user VALUES(%s,%s,%s,%s,%s,%s)"""
data=mus.values.tolist()
mycursor.executemany(query,data)

# %%
c=mycursor.execute("SELECT * FROM map_user ")
c=mycursor.fetchall()
for i in c:
    print(i)
# Out:
# ('andaman & nicobar islands', '2018', '1', 'north and middle andaman ', '632', '0')
# ('andaman & nicobar islands', '2018', '1', 'south andaman ', '5846', '0')
# ('andaman & nicobar islands', '2018', '1', 'nicobars ', '262', '0')
# ('andaman & nicobar islands', '2018', '2', 'north and middle andaman ', '911', '0')
# ('andaman & nicobar islands', '2018', '2', 'south andaman ', '8143', '0')
# ('andaman & nicobar islands', '2018', '2', 'nicobars ', '351', '0')
# ('andaman & nicobar islands', '2018', '3', 'north and middle andaman ', '1208', '0')
# ('andaman & nicobar islands', '2018', '3', 'south andaman ', '10474', '0')
# ('andaman & nicobar islands', '2018', '3', 'nicobars ', '467', '0')
# ('andaman & nicobar islands', '2018', '4', 'north and middle andaman ', '1553', '0')
# ('andaman & nicobar islands', '2018', '4', 'south andaman ', '13133', '0')
# ('andaman & nicobar islands', '2018', '4', 'nicobars ', '536', '0')
# ...

# %%
# Create Data frame for top\transaction

import os
import json
import pandas as pd

path="C:\\Users\\91909\\firstprogram\\Phonepe\\pulse\\data\\top\\transaction\\country\\india\\state\\"


top_trans_st=os.listdir(path)
top_trans_st

tts={'State':[], 'Year':[],'Quater':[],'District':[], 'District_count':[], 'District_amount':[]}
for i in top_trans_st:
  tr_st=path+i+'/'
  agg_year=os.listdir(tr_st)
  for j in agg_year:
    tr_yr=tr_st+j+'/'
    agg_yr_list=os.listdir(tr_yr)
    for k in agg_yr_list:
      tr_j=tr_yr+k
      data=open(tr_j,'r')
      d=json.load(data)
      if d['data']["districts"] == None :
            continue
      else:      
          for z in d['data']["districts"]:
#              print(z['brand'],i,j,int(k.strip('.json')))
             Name=z['entityName']
             Count=z['metric']['count']
             Amount=z['metric']['amount']
             tts['State'].append(i.replace('-',' '))
             tts['Year'].append(j)
             tts['Quater'].append(int(k.strip('.json')))
             tts['District_amount'].append(Amount)
             tts['District_count'].append(Count)
             tts['District'].append(Name)

tts=pd.DataFrame(tts)       
tts
# Out:
#                           State  Year  Quater                    District  \
# 0     andaman & nicobar islands  2018       1               south andaman
# 1     andaman & nicobar islands  2018       1                    nicobars
# 2     andaman & nicobar islands  2018       1    north and middle andaman
# 3     andaman & nicobar islands  2018       2               south andaman
# 4     andaman & nicobar islands  2018       2                    nicobars
# ...                         ...   ...     ...                         ...
# 5915                west bengal  2022       4  south twenty four parganas
# 5916                west bengal  2022       4             purba medinipur
# 5917                west bengal  2022       4                     hooghly
# 5918                west bengal  2022       4                      howrah
# 5919                west bengal  2022       4           paschim medinipur
#
#       District_count  District_amount
# 0               5688     1.256025e+07
# ...

# %%
mycursor.execute("""CREATE TABLE IF NOT EXISTS top_transation(
                        State TEXT,Year TEXT,Quater TEXT,District TEXT,District_count TEXT,District_amount TEXT)"""
                )

# %%
query="""INSERT INTO top_transation VALUES(%s,%s,%s,%s,%s,%s)"""
data=tts.values.tolist()
mycursor.executemany(query,data)

# %%
c=mycursor.execute("SELECT * FROM top_transation ")
c=mycursor.fetchall()
for i in c:
    print(i)
# Out:
# ('andaman & nicobar islands', '2018', '1', 'south andaman', '5688', '12560249.343665812')
# ('andaman & nicobar islands', '2018', '1', 'nicobars', '528', '1139848.801225994')
# ('andaman & nicobar islands', '2018', '1', 'north and middle andaman', '442', '931663.0770939873')
# ('andaman & nicobar islands', '2018', '2', 'south andaman', '9395', '23948235.51634325')
# ('andaman & nicobar islands', '2018', '2', 'nicobars', '1120', '3072436.9081196385')
# ('andaman & nicobar islands', '2018', '2', 'north and middle andaman', '825', '1317863.0834906558')
# ('andaman & nicobar islands', '2018', '3', 'south andaman', '13511', '44268112.46425246')
# ('andaman & nicobar islands', '2018', '3', 'nicobars', '1471', '6387829.151558982')
# ('andaman & nicobar islands', '2018', '3', 'north and middle andaman', '1283', '4901529.518499676')
# ('andaman & nicobar islands', '2018', '4', 'south andaman', '20136', '75411840.8018554')
# ...

# %%
# Create Data frame for top\User

import os
import json
import pandas as pd

path="C:\\Users\\91909\\firstprogram\\Phonepe\\pulse\\data\\top\\user\\country\\india\\state\\"


top_user_st=os.listdir(path)
top_user_st

tus={'State':[], 'Year':[],'Quater':[], 'pincodes':[],'p_registeredUsers':[]}
tas={'State':[], 'Year':[],'Quater':[],'District':[], 'registeredUsers':[]}

for i in top_user_st:
  tr_st=path+i+'/'
  agg_year=os.listdir(tr_st)
  for j in agg_year:
    tr_yr=tr_st+j+'/'
    agg_yr_list=os.listdir(tr_yr)
    for k in agg_yr_list:
      tr_j=tr_yr+k
      data=open(tr_j,'r')
      d=json.load(data)
      for key,val in d['data'].items():
#         if key=='districts':
#            for z in  val:
                
#                 Name1=z['name']
#                 Reg_user1=z['registeredUsers']
#                 tas['District'].append(Name1)
# #                 print(len(tas['District']))
#                 tas['registeredUsers'].append(Reg_user1)
# #                 print(len(tas['registeredUsers']))
#                 tas['State'].append(i)
#                 tas['Year'].append(j)
#                 tas['Quater'].append(int(k.strip('.json')))
    
    
        if key== 'pincodes':
           for l in  val:
                Name=l['name']
                Reg_user=l['registeredUsers']   
                tus['pincodes'].append(Name)
        #              print(len(tus['pincodes']))   
                tus['p_registeredUsers'].append(Reg_user)
#                 print(len(tus['p_registeredUsers'])) 
                tus['State'].append(i.replace('-',' '))
        #              print(len(tus['State'])) 
                tus['Year'].append(j)
        #              print(len(tus['Year'])) 
                tus['Quater'].append(int(k.strip('.json')))
        #              print(len(tus['Quater'])) 
                

      
tus=pd.DataFrame(tus)
# tas=pd.DataFrame(tas)
# tas
tus
# Out:
#                           State  Year  Quater pincodes  p_registeredUsers
# 0     andaman & nicobar islands  2018       1   744103               1608
# 1     andaman & nicobar islands  2018       1   744101               1108
# 2     andaman & nicobar islands  2018       1   744105               1075
# 3     andaman & nicobar islands  2018       1   744102               1006
# 4     andaman & nicobar islands  2018       1   744104                272
# ...                         ...   ...     ...      ...                ...
# 7135                west bengal  2022       4   700015             108457
# 7136                west bengal  2022       4   742304             105471
# 7137                west bengal  2022       4   721101             105279
# 7138                west bengal  2022       4   700091             102363
# 7139                west bengal  2022       4   700150             101966
#
# [7140 rows x 5 columns]

# %%
tus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7140 entries, 0 to 7139
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   State              7140 non-null   object
#  1   Year               7140 non-null   object
#  2   Quater             7140 non-null   int64
#  3   pincodes           7140 non-null   object
#  4   p_registeredUsers  7140 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 279.0+ KB

# %%
tus['pincodes']=tus['pincodes'].apply(pd.to_numeric)

# %%
tus
# Out:
#                           State  Year  Quater  pincodes  p_registeredUsers
# 0     andaman & nicobar islands  2018       1    744103               1608
# 1     andaman & nicobar islands  2018       1    744101               1108
# 2     andaman & nicobar islands  2018       1    744105               1075
# 3     andaman & nicobar islands  2018       1    744102               1006
# 4     andaman & nicobar islands  2018       1    744104                272
# ...                         ...   ...     ...       ...                ...
# 7135                west bengal  2022       4    700015             108457
# 7136                west bengal  2022       4    742304             105471
# 7137                west bengal  2022       4    721101             105279
# 7138                west bengal  2022       4    700091             102363
# 7139                west bengal  2022       4    700150             101966
#
# [7140 rows x 5 columns]

# %%
tus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7140 entries, 0 to 7139
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   State              7140 non-null   object
#  1   Year               7140 non-null   object
#  2   Quater             7140 non-null   int64
#  3   pincodes           7140 non-null   object
#  4   p_registeredUsers  7140 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 279.0+ KB

# %%
tus.isnull().sum()
# Out:
# State                0
# Year                 0
# Quater               0
# pincodes             0
# p_registeredUsers    0
# dtype: int64

# %%
mycursor.execute("""USE  phonepe""")

# %%
mycursor.execute("""CREATE TABLE IF NOT EXISTS top_users(
                        State TEXT,Year TEXT,Quater TEXT,pincodes TEXT,p_registeredUsers TEXT)"""
                )
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     564                 query = query.encode("utf-8")
# --> 565             self._cmysql.query(
#     566                 query,
#
# MySQLInterfaceError: Lost connection to MySQL server during query
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13688\1430057871.py in <cell line: 1>()
# ----> 1 mycursor.execute("""CREATE TABLE IF NOT EXISTS top_users(
#       2                         State TEXT,Year TEXT,Quater TEXT,pincodes TEXT,p_registeredUsers TEXT)"""
#       3                 )
#
# ...

# %%
query="""INSERT INTO top_users VALUES(%s,%s,%s,%s,%s)"""
data=tus.values.tolist()
mycursor.executemany(query,data)

# %%
c=mycursor.execute("SELECT * FROM top_users ")
c=mycursor.fetchall()

for i in c:
    print(i)
# Out:
# ('andaman & nicobar islands', '2018', '1', '744103', '1608')
# ('andaman & nicobar islands', '2018', '1', '744101', '1108')
# ('andaman & nicobar islands', '2018', '1', '744105', '1075')
# ('andaman & nicobar islands', '2018', '1', '744102', '1006')
# ('andaman & nicobar islands', '2018', '1', '744104', '272')
# ('andaman & nicobar islands', '2018', '1', '744202', '237')
# ('andaman & nicobar islands', '2018', '1', '744112', '215')
# ('andaman & nicobar islands', '2018', '1', '744301', '207')
# ('andaman & nicobar islands', '2018', '1', '744107', '196')
# ('andaman & nicobar islands', '2018', '1', '744211', '156')
# ('andaman & nicobar islands', '2018', '2', '744103', '2188')
# ('andaman & nicobar islands', '2018', '2', '744101', '1521')
# ('andaman & nicobar islands', '2018', '2', '744105', '1492')
# ('andaman & nicobar islands', '2018', '2', '744102', '1419')
# ('andaman & nicobar islands', '2018', '2', '744104', '396')
# ('andaman & nicobar islands', '2018', '2', '744202', '343')
# ...

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd
import plotly.express as px
import pydeck as pdk
from numerize import numerize
import locale
import babel.numbers
import mysql.connector

mydb=mysql.connector.connect(
    host='localhost',
    user='root',
    password='',
)
mycursor=mydb.cursor(buffered=True)
mycursor.execute("USE Phonepe")

st.set_page_config(
    page_title="Phonepe Pulse",
    page_icon="🧊",
    layout="wide",
    initial_sidebar_state="expanded",
    menu_items={
        'Get Help': 'https://www.extremelycoolapp.com/',
        'Report a bug': "https://www.extremelycoolapp.com/bug",
        'About': "# This is a header. This is an *extremely* cool app!"
    }
)

title=st.title("Phonepe")

col1, col2, col3 = st.columns([1,1,1])

    

#Dropdown list State

mycursor.execute("SELECT DISTINCT State FROM agg_user")
c=mycursor.fetchall()
state=[]
for i in c:
    
    state.append(*i)
    
with col1 :    
    state_db_1 = st.selectbox('State',(state),key='State_drpdwn-1')    #Dropdown

# dropdown list for Quater

mycursor.execute("SELECT DISTINCT Quater FROM agg_user")

c=mycursor.fetchall()
quater=[]
for i in c:
    
    quater.append(*i)
with col1 :    
    quater_db_1=st.selectbox('Quater',(quater),key='Quater_drpdwn-1')
    
#dropdown list for Year
    
mycursor.execute("SELECT DISTINCT Year FROM agg_user")
c=mycursor.fetchall()
year=[]
for i in c:
    
    year.append(*i)
with col1 :    
    year_db_1=st.selectbox('Year',(year),key='Year_drpdwn-1')    

 
import plotly.express as px
# state_db_1=state_db_1.replace('-',' ')

mycursor.execute(f"SELECT * FROM top_transation WHERE State='{state_db_1}' AND Year='{year_db_1}' AND Quater={quater_db_1} ")

table_rows = mycursor.fetchall()

df = pd.DataFrame(table_rows,columns=['State','Year','Quater','District','District_count','District_amount'])
df['State']=df['State'].str.replace('-',' ')
df['Year']=df['Year'].astype(int)
df['Quater']=df['Quater'].astype(int)
# df['pincode']=df['pincode'].astype(int)
# df['District_count']=df['District_count'].astype(float)
# df['District_amount']=df['District_amount'].astype(float)



#Pincode Map Csv
map_df=pd.read_csv(r'C:\\Users\\91909\\firstprogram\\Phonepe\\zip_to_lat_lon_India_1.csv',low_memory=False)
map_df=map_df[map_df['Country']=='India']
map_df.drop(['state','place','statecode','province_or_countycode','community','communitycode','accuracy','Continent','Country','country code'],axis=1,inplace=True)
map_df.reset_index(drop=True,inplace=True)
map_df.rename(columns = {'province_or_county':'District','postal code':'pincode'}, inplace = True)
# map_df['state']=map_df['state'].apply(str)
# map_df['state']=map_df['state'].apply(str.lower)
map_df['District']=map_df['District'].apply(str)
map_df['District']=map_df['District'].apply(str.lower)
map_df['pincode'] = map_df['pincode'].drop_duplicates(keep='last')

map_df.dropna(axis=0,inplace=True)
map_df['pincode']=map_df['pincode'].astype(int)
map_df.reset_index(drop=True)

chart_data=df.merge(map_df,on='District', how='left')

chart=pd.DataFrame(chart_data)

chart.drop_duplicates(subset=['Year','Quater','District','District_count','District_amount'],keep='last',inplace=True)
chart.reset_index(drop=True,inplace=True)

chart1=chart.groupby(["District","latitude","longitude"])['District_amount'].sum().reset_index()

# st.dataframe(chart)
# with col2:    
#     st.pydeck_chart(pdk.Deck(
#          map_style=None,
#          initial_view_state=pdk.ViewState(
#              latitude=11.820233628491849,
#              longitude=79.27937299999995,
#              zoom=4,      
#              pitch=50,
#           ),
#          layers=[
#               pdk.Layer(
#                    'HexagonLayer',
#                    data=chart1,
#                    get_position=['longitude', 'latitude'],
#                    get_color=[200, 30, 0, 160],
#                    get_radius=200,
#                    auto_highlight=True,
#                    elevation_scale=50,
#                    pickable=True,
#                    elevation_range=[0, 3000],
#                    extruded=True,
#                    coverage=1,
#                 ),
            
#          ],
#      ))
    
# Transaction Details

with st.sidebar:
    

        st.markdown(
        f'''
            <style>
                .sidebar .sidebar-content {{
                    width: 375px;
                }}
            </style>
        ''',
        unsafe_allow_html=True
         )
        st.markdown(f'<div style="font-size: 25px;color:#00FFFF;"><b>Transactions</b></div>', unsafe_allow_html=True)
        mycursor.execute(f"SELECT sum(Transacion_count) FROM agg_trans WHERE State='{state_db_1}' AND Year='{year_db_1}' AND Quater={quater_db_1}")

        for i in mycursor:

            s=babel.numbers.format_currency(int(*i), 'INR', locale="en_IN")   
            st.metric(label="All PhonePe transactions (UPI + Cards + Wallets)",value=s)

        #Total payment value
        mycursor.execute(f"SELECT sum(Transacion_amount) FROM agg_trans WHERE State='{state_db_1}' AND Year='{year_db_1}' AND Quater={quater_db_1}")

        for i in mycursor:

    #         s=babel.numbers.format_currency(int(*i), 'INR', locale="en_IN")  
            i=int(*i)
            value = i / 10000000

            humanized = locale.format('%d', value, grouping=True)
            s = humanized + ' ' + 'Cr'
            st.metric(label="Total payment value",value=s)

            st.markdown(f'<div style="font-size: 25px;color:#00FFFF;"><b>Categories</b></div>', unsafe_allow_html=True)

    
        mycursor.execute(f"""SELECT Transacion_type, sum(Transacion_count) 
             FROM agg_trans WHERE State='{state_db_1}' AND Year='{year_db_1}' AND Quater={quater_db_1} GROUP BY Transacion_type order by count(Transacion_count) """)

        table_rows = mycursor.fetchall()
        st.write(" ")   
        for i,j in table_rows:

            s=babel.numbers.format_currency(int(j), 'INR', locale="en_IN") 

            st.write(i)
    #         trans_type=st.write(s)
            st.markdown(f'<div style="text-align: right;margin-top:-39px">{s}</div>', unsafe_allow_html=True)
  
        tab1, tab2,= st.tabs(["District", "Pincodes"]) 
        with tab1:
            st.markdown(f'<div style="font-size: 25px;color:#00FFFF;"><b>Top 10 District </b></div>', unsafe_allow_html=True)
            mycursor.execute(f"""SELECT District, sum(District_count) FROM top_transation 
             WHERE State='{state_db_1}' AND Year='{year_db_1}' AND Quater={quater_db_1} GROUP BY District order by count(District_count) """)
            table_rows = mycursor.fetchall()
            st.write(" ")   
            for i,j in table_rows:

        #         s=babel.numbers.format_currency(int(j), 'INR', locale="en_IN") 
                st.write(i)

                j=int(j)
                s=babel.numbers.format_currency(int(j), 'INR', locale="en_IN") 

                st.markdown(f'<div style="text-align: right;margin-top:-39px">{s}</div>', unsafe_allow_html=True)

        with tab2:
            st.markdown(f'<div style="font-size: 25px;color:#00FFFF;"><b>Top 10 Pincodes </b></div>', unsafe_allow_html=True)
            mycursor.execute(f"""SELECT pincodes,p_registeredUsers FROM top_users 
             WHERE State='{state_db_1}' AND Year='{year_db_1}' AND Quater={quater_db_1} GROUP BY pincodes order by sum(p_registeredUsers) """)
            table_rows = mycursor.fetchall()
            st.write(" ")   
            for i,j in table_rows:

        #         s=babel.numbers.format_currency(int(j), 'INR', locale="en_IN") 

        #         s=babel.numbers.format_currency(int(j), 'INR', locale="en_IN") 
                st.write(i)

                j=int(j)
                s=babel.numbers.format_currency(int(j), 'INR', locale="en_IN") 

                st.markdown(f'<div style="text-align: right;margin-top:-39px">{s}</div>', unsafe_allow_html=True)

mycursor.execute(f"SELECT * FROM top_transation WHERE State='{state_db_1}' AND Year='{year_db_1}' AND Quater={quater_db_1} ")
data=mycursor.fetchall()
result = pd.DataFrame(data,columns=['state','Year','Quater','District','District_count','District_amount'])

label=result.groupby('District')['District_count','District_amount'].sum().reset_index()

    
s=label['District_amount'].apply(lambda x: (babel.numbers.format_currency(float(x), 'INR', locale="en_IN") ))
see=label['District_count'].apply(lambda x: (babel.numbers.format_currency(float(x), 'INR', locale="en_IN") ))

fig=px.bar(label,x='District',y=s,color='District',hover_data=[see],
           labels={'District_count':'All Transaction','y':'Total payment value','hover_data_0':'All Transaction'})  
fig.update_layout(
    yaxis= {'title': 'y-axis',
         'visible': False,
         'showticklabels': False},
)
st.write(fig)



# fig=px.bar(label,x='District',y='District_amount',color='District',hover_data=['District_count'],
#            labels={'District_amount':'All Transaction','District_count':'Total payment value'})  
# st.write(fig)
# Out:
# Overwriting app.py

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\91909\\firstprogram\\Phonepe'

# %%
import locale
from math import log10
def sexify(value):
    MAP = {
            0: '',
            1: '',
            2: '',
            3: 'Thousand',
            4: 'Thousand',
            5: 'Lakh',
            6: 'Lakh',
            7: 'Crore',
            8: 'Crore',
        }
    power = int(log10(abs(value)))
    if power <= 8:

        humanized = locale.format('%d', value, grouping=True)
        rounded = humanized[:4].replace(',', '.')
        s = rounded + ' ' + MAP[power]
        if (rounded != '1.00'): s = s + 's'
    else:
        value = value / 10000000
        humanized = locale.format('%d', value, grouping=True)
        s = humanized + ' ' + 'Crores'

    print(s)
sexify(3984674.4287863)
# Out:
# 3984 Lakhs
# C:\Users\91909\AppData\Local\Temp\ipykernel_13688\3176689601.py:18: DeprecationWarning: This method will be removed in a future version of Python. Use 'locale.format_string()' instead.
#   humanized = locale.format('%d', value, grouping=True)

# %%
values=3984674404.4287863
value = values / 10000000
print(value)
humanized = locale.format('%d', value, grouping=True)
print(humanized)
s = humanized + ' ' + 'Crores'
print(s)
# Out:
# 398.4674404428786
# 398
# 398 Crores
# C:\Users\91909\AppData\Local\Temp\ipykernel_13688\4082753962.py:4: DeprecationWarning: This method will be removed in a future version of Python. Use 'locale.format_string()' instead.
#   humanized = locale.format('%d', value, grouping=True)

# %%
# !pip install pgeocode
# Out:
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
